# %% [markdown]
# <a href="https://colab.research.google.com/github/Arron-Harris/plotly-data-visualization/blob/main/plotly_stocks_visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I will use plotly to see which company stock I should have invested in to get the highest return.

# %%
import plotly.express as px
import pandas as pd
import seaborn as sns
import plotly

# %%
stocks = px.data.stocks(indexed=True)
stocks.head()
# Out:
# company         GOOG      AAPL      AMZN        FB      NFLX      MSFT
# date
# 2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
#Create a line graph for the stocks
px.line(stocks, line_shape='spline')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# I would go with the microsoft stock if I could go back to 2018.

# %%
px.area(stocks)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
